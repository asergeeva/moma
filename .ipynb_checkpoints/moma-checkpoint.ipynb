# %% [markdown]
# # 1. The MoMA Collection As It Relates to Me
#
# As an artist I was curious to learn: what are my own personal odds of getting into the group of 15,222 artists whose work is represented in the MoMA Collection? Given that the artist bio includes nationality, birth country (if other than their classified nationality) as well as gender, I was interested in using both metrics to understand my own percentage.
#
# How many of these artists are women?
# How many are from Ukraine?
# How many are both?
# And who are they?

# %% [markdown]
# ## 1.1 How many of these artists are women?

# %%
# !pip install pandas
import pandas as pd

# %%
# loading data
df_artists = pd.read_csv('https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artists.csv')

# %%
# inspecting data
df_artists.head()
# Out:
#    ConstituentID      DisplayName            ArtistBio Nationality Gender  \
# 0              1   Robert Arneson  American, 1930–1992    American   Male
# 1              2   Doroteo Arnaiz   Spanish, born 1936     Spanish   Male
# 2              3      Bill Arnold  American, born 1941    American   Male
# 3              4  Charles Arnoldi  American, born 1946    American   Male
# 4              5      Per Arnoldi    Danish, born 1941      Danish   Male
#
#    BeginDate  EndDate  Wiki QID         ULAN
# 0       1930     1992       NaN          NaN
# 1       1936        0       NaN          NaN
# 2       1941        0       NaN          NaN
# 3       1946        0  Q1063584  500027998.0
# 4       1941        0       NaN          NaN

# %%
#the gender column

df_artists['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#          ...
# 15217    Male
# 15218    Male
# 15219     NaN
# 15220     NaN
# 15221     NaN
# Name: Gender, Length: 15222, dtype: object

# %%
#the rows of artist's whose gender is Female

df_artists[df_artists.Gender == 'Female']
# Out:
#        ConstituentID                DisplayName  \
# 8                 10              Irene Aronson
# 16                21                 Ruth Asawa
# 17                22           Isidora Aschheim
# 23                28             Geneviève Asse
# 25                31               Dana Atchley
# ...              ...                        ...
# 15199         132407  Hulleah J. Tsinhnahjinnie
# 15200         132412            Tatiana Parcero
# 15202         132441                  Suzy Lake
# 15205         132545                   Ann Tyng
# 15206         132547             Wendy Red Star
#
#                                                ArtistBio      Nationality  \
# 8                            American, born Germany 1918         American
# 16                                   American, 1926–2013         American
# 17                                               Israeli          Israeli
# 23                                     French, born 1923           French
# ...

# %% [markdown]
# There are 2,300 artists who are female out of 15,222 artists in the MoMA collection. That means only 15% of the artists in the MoMA Collection are women. At least it's gotten a bit better since 1997...

# %% [markdown]
# ![gg.jpg](attachment:7fd90f13-e790-4597-8666-fb4d91ecc43e.jpg)

# %%
#doublechecking the full Gender breakdown to see if I'm missing anything
df_artists['Gender'].unique()
# Out:
# array(['male', 'female', nan, 'non-binary'], dtype=object)

# %%
#now I see there are various capitalization differences across the data, so let's see those counts!
df_artists['Gender'].value_counts()
# Out:
# male          9343
# female        2136
# non-binary       3
# Name: Gender, dtype: int64

# %%
df_artists['Gender'] = df_artists['Gender'].str.lower()
#doing this to lowercase all of the gender descriptors so that the numbers are grouped together properly

# %%
df_artists['Gender'].unique()
# Out:
# array(['male', 'female', nan, 'non-binary'], dtype=object)

# %% [markdown]
# Though a bit of a digression from my initial question, I was curious to learn how many artists in the collection are classified as non-Binary.

# %%
df_artists[df_artists.Gender == 'non-binary']
# Out:
#        ConstituentID    DisplayName            ArtistBio Nationality  \
# 11573          34902  Sadie Benning  American, born 1973    American
# 14959          74347  Patrick Staff   British, born 1987     British
# 15208         132720     Tourmaline  American, born 1983    American
#
#            Gender  BeginDate  EndDate Wiki QID         ULAN
# 11573  non-binary       1973        0  Q448193  500114576.0
# 14959  non-binary       1987        0      NaN          NaN
# 15208  non-binary       1983        0      NaN          NaN

# %% [markdown]
# There are only three.

# %%
# !pip install seaborn
import seaborn as sns

# %%
gender_count  = df_artists['Gender'].value_counts()
gender_count = gender_count[:10,]
plt.figure(figsize=(10,5))
sns.barplot(gender_count.index, gender_count.values, alpha=0.8)
plt.title('Gender Breakdown in the MoMA Collection')
plt.ylabel('Total Number', fontsize=12)
plt.xlabel('Gender', fontsize=12)
plt.show()
# Out:
# /Users/annasergeeva/opt/anaconda3/envs/moma/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 1.2 How many of these artists are from Ukraine?

# %% [markdown]
# Let's see which nationalities are represented across the artists in the MoMA Collection!

# %%
df_artists['Nationality'].unique()
# Out:
# array(['american', 'spanish', 'danish', 'italian', 'french', 'estonian',
#        'mexican', 'swedish', nan, 'israeli', 'british', 'finnish',
#        'polish', 'palestinian', 'japanese', 'guatemalan', 'colombian',
#        'romanian', 'russian', 'german', 'argentine', 'kuwaiti', 'belgian',
#        'dutch', 'norwegian', 'nationality unknown', 'chilean', 'swiss',
#        'costa rican', 'czech', 'brazilian', 'austrian', 'canadian',
#        'australian', 'ukrainian', 'hungarian', 'haitian', 'congolese',
#        'bolivian', 'cuban', 'yugoslav', 'portuguese', 'indian',
#        'peruvian', 'icelandic', 'irish', 'guyanese', 'uruguayan',
#        'slovak', 'croatian', 'greek', 'chinese', 'venezuelan', 'turkish',
#        'panamanian', 'algerian', 'ecuadorian', 'south african', 'iranian',
#        'korean', 'canadian inuit', 'paraguayan', 'luxembourgish',
#        'nicaraguan', 'zimbabwean', 'moroccan', 'slovenian', 'tanzanian',
# ...

# %%
df_artists['Nationality'] = df_artists['Nationality'].str.lower()

# %%
df_artists[df_artists.Nationality == 'ukrainian']
# Out:
#        ConstituentID                DisplayName             ArtistBio  \
# 283              325  Vladimir Baranoff-Rossiné  Ukrainian, 1888–1944
# 784              877              David Burliuk  Ukrainian, 1882–1967
# 2898            3248           Vasyl Krychevsky   Ukranian, born 1927
# 7176            8168            Boris Mikhailov  Ukrainian, born 1938
# 8552           12001           Vladimir Burliuk  Ukrainian, 1886–1917
# 9080           23522                  Mane-Katz  Ukrainian, 1894–1962
# 9156           23842           Mykhailo Semenko  Ukrainian, 1892–1937
# 9265           24211        Anatol' Petryts'kyi  Ukrainian, 1895–1964
# 10851          31069               Peter Weibel   Ukranian, born 1944
# 11057          32230        Alexander Dovzhenko  Ukrainian, 1894–1956
# 11683          35448         Alexander Roitburd  Ukrainian, born 1961
#
#       Nationality Gender  BeginDate  EndDate  Wiki QID         ULAN
# ...

# %% [markdown]
# All of the Ukrainian artists are male. :( Let's see if there are any artists with a nationality other than Ukrainian, but who are born in Ukraine. This information is in the Artist Bio column.

# %%
df_artists['ArtistBio'] = df_artists['ArtistBio'].str.lower()

# %%
df_artists = df_artists.dropna(subset = ['ArtistBio'])

#to drop the NA ArtistBio rows from the set.

# %%
df_artists.shape

#to see how many rows are left
# Out:
# (13017, 9)

# %%
df_artists[df_artists['ArtistBio'].str.contains('ukrain')]

#to see which ArtistBio rows contain 'Ukrain'
# Out:
#        ConstituentID                DisplayName  \
# 180              209       Aleksandr Archipenko
# 283              325  Vladimir Baranoff-Rossiné
# 406              463                   Ben-Zion
# 784              877              David Burliuk
# 1310            1480        Sonia Delaunay-Terk
# 2030            2284             John D. Graham
# 2433            2732         Philippe Hosiasson
# 3191            3574              Israel Litwak
# 3228            3617             Louis Lozowick
# 3319            3710           Kazimir Malevich
# 3367            3762                Boris Margo
# 3831            4278            Louise Nevelson
# 4366            4873             Milton Resnick
# 4851            5420             Maurice Sievan
# 4929            5503                Janet Sobel
# 5897            6579              Harry Zolotow
# 7176            8168            Boris Mikhailov
# 8552           12001           Vladimir Burliuk
# ...

# %% [markdown]
# ## 1.3 How many of these artists are from Ukraine and are female?

# %%
df_artists[(df_artists['ArtistBio'].str.contains('ukrain')) & (df_artists['Gender'] == 'female')]

#to see which ArtistBio rows contain 'Ukrain' and female simultaneously
# Out:
#       ConstituentID          DisplayName                          ArtistBio  \
# 1310           1480  Sonia Delaunay-Terk    french, born ukraine. 1885–1979
# 3831           4278      Louise Nevelson  american, born ukraine. 1899–1988
# 4929           5503          Janet Sobel  american, born ukraine. 1894–1968
# 9336          24459         Olga Deineko   russian, born ukraine. 1897–1970
#
#      Nationality  Gender  BeginDate  EndDate  Wiki QID         ULAN
# 1310      french  female       1885     1979   Q232972  500115510.0
# 3831    american  female       1899     1988     Q7531  500001621.0
# 4929    american  female       1894     1968  Q6153610          NaN
# 9336     russian  female       1897     1970       NaN          NaN

# %% [markdown]
# There are only four women from Ukraine in the MoMA collection. That means my chances are 4/15222 which is 0.026%. I guess I'll have to be the fifth!!
